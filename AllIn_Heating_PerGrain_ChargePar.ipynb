# %% [markdown]
# # Photoelectric heating rate per grain as a funciton of charge.
#
# Panel Figure 1. Pe_heat as a function of charge for three grain sizes.

# %%
import compute_charge_dist as fz
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate

import PeHeat_Functions as peh

# %matplotlib inline

microntocm    = 1.0e-4
cmtomicron    = 1.0e4
AAtocm        = 1.0e-8
cmtoAA        = 1.0e8
microntoAA    = 1.0e4
AAtomicron    = 1.0e-4
ergtoeV       = 6.242e11
eVtoerg       = 1.602e-12

hplanck       = 4.135667662e-15 # eV s
clight        = 2.99792458e10   # cm s-1
# Out:
# Loading the library to compute the charge distribution of dust grains.

# %% [markdown]
# # Panel Figure 1
#
# photoelectric heating rate as a function of the grain charge and the incident radiation field for various sizes.

# %%
grain_type="silicate"

asize = 5.
Ntot = 0.0

Qabs = fz.get_QabsTable(grain_type, asize)

Zmin_sil, Zmax_sil = fz.get_Zmin(asize, grain_type), fz.get_Zmax(asize, grain_type)
Znum_sil = int(Zmax_sil + abs(Zmin_sil) +1)
ZZ_sil = np.linspace(Zmin_sil, Zmax_sil, num=Znum_sil)

Gamma_dotdot_Z_sil = np.zeros_like(ZZ_sil)

for i in range(Znum_sil):
    Gamma_dotdot_Z_sil[i] = peh.get_Gamma_pe_dotdot(asize, ZZ_sil[i], grain_type, Ntot, Qabs, G0=1.7)
    
ZZ_sil_5AA             = np.concatenate(([Zmin_sil-1], ZZ_sil))
Gamma_dotdot_Z_sil_5AA = np.concatenate(([Gamma_dotdot_Z_sil[0]], Gamma_dotdot_Z_sil))
# Out:
# I'm looking for a grain size smaller than 10 Angstrom. Outside the tabulated data!!!
# Using the absorption efficiency for a 10 AA grain

# %%
asize = 100.
Ntot = 0.0

Qabs = fz.get_QabsTable(grain_type, asize)

Zmin_sil, Zmax_sil = fz.get_Zmin(asize, grain_type), fz.get_Zmax(asize, grain_type)
Znum_sil = int(Zmax_sil + abs(Zmin_sil) +1)
ZZ_sil = np.linspace(Zmin_sil, Zmax_sil, num=Znum_sil)

Gamma_dotdot_Z_sil = np.zeros_like(ZZ_sil)

for i in range(Znum_sil):
    Gamma_dotdot_Z_sil[i] = peh.get_Gamma_pe_dotdot(asize, ZZ_sil[i], grain_type, Ntot, Qabs, G0=1.7)
    
ZZ_sil_100AA             = np.concatenate(([Zmin_sil-1], ZZ_sil))
Gamma_dotdot_Z_sil_100AA = np.concatenate(([Gamma_dotdot_Z_sil[0]], Gamma_dotdot_Z_sil))

# %%
asize = 1000.
Ntot = 0.0

Qabs = fz.get_QabsTable(grain_type, asize)

Zmin_sil, Zmax_sil = fz.get_Zmin(asize, grain_type), fz.get_Zmax(asize, grain_type)
Znum_sil = int(Zmax_sil + abs(Zmin_sil) +1)
ZZ_sil = np.linspace(Zmin_sil, Zmax_sil, num=Znum_sil)

Gamma_dotdot_Z_sil = np.zeros_like(ZZ_sil)

for i in range(Znum_sil):
    Gamma_dotdot_Z_sil[i] = peh.get_Gamma_pe_dotdot(asize, ZZ_sil[i], grain_type, Ntot, Qabs, G0=1.7)
    
ZZ_sil_1000AA             = np.concatenate(([Zmin_sil-1], ZZ_sil))
Gamma_dotdot_Z_sil_1000AA = np.concatenate(([Gamma_dotdot_Z_sil[0]], Gamma_dotdot_Z_sil))

# %%
print("Done")
# Out:
# Done

# %% [markdown]
# ---

# %%
grain_type="carbonaceous"

asize = 5.
Ntot = 0.0

Qabs = fz.get_QabsTable(grain_type, asize)

Zmin_carb, Zmax_carb = fz.get_Zmin(asize, grain_type), fz.get_Zmax(asize, grain_type)
Znum_carb = int(Zmax_carb + abs(Zmin_carb) +1)
ZZ_carb = np.linspace(Zmin_carb, Zmax_carb, num=Znum_carb)

Gamma_dotdot_Z_carb = np.zeros_like(ZZ_carb)

for i in range(Znum_carb):
    Gamma_dotdot_Z_carb[i] = peh.get_Gamma_pe_dotdot(asize, ZZ_carb[i], grain_type, Ntot, Qabs, G0=1.7)
    
ZZ_carb_5AA             = np.concatenate(([Zmin_carb-1], ZZ_carb))
Gamma_dotdot_Z_carb_5AA = np.concatenate(([Gamma_dotdot_Z_carb[0]], Gamma_dotdot_Z_carb))
# Out:
# I'm looking for a grain size smaller than 10 Angstrom. Outside the tabulated data!!!
# Using the absorption efficiency for a 10 AA grain

# %%
asize = 100.
Ntot = 0.0

Qabs = fz.get_QabsTable(grain_type, asize)

Zmin_carb, Zmax_carb = fz.get_Zmin(asize, grain_type), fz.get_Zmax(asize, grain_type)
Znum_carb = int(Zmax_carb + abs(Zmin_carb) +1)
ZZ_carb = np.linspace(Zmin_carb, Zmax_carb, num=Znum_carb)

Gamma_dotdot_Z_carb = np.zeros_like(ZZ_carb)

for i in range(Znum_carb):
    Gamma_dotdot_Z_carb[i] = peh.get_Gamma_pe_dotdot(asize, ZZ_carb[i], grain_type, Ntot, Qabs, G0=1.7)
    
ZZ_carb_100AA             = np.concatenate(([Zmin_carb-1], ZZ_carb))
Gamma_dotdot_Z_carb_100AA = np.concatenate(([Gamma_dotdot_Z_carb[0]], Gamma_dotdot_Z_carb))

# %%
asize = 1000.
Ntot = 0.0

Qabs = fz.get_QabsTable(grain_type, asize)

Zmin_carb, Zmax_carb = fz.get_Zmin(asize, grain_type), fz.get_Zmax(asize, grain_type)
Znum_carb = int(Zmax_carb + abs(Zmin_carb) +1)
ZZ_carb = np.linspace(Zmin_carb, Zmax_carb, num=Znum_carb)

Gamma_dotdot_Z_carb = np.zeros_like(ZZ_carb)

for i in range(Znum_carb):
    Gamma_dotdot_Z_carb[i] = peh.get_Gamma_pe_dotdot(asize, ZZ_carb[i], grain_type, Ntot, Qabs, G0=1.7)
    
ZZ_carb_1000AA             = np.concatenate(([Zmin_carb-1], ZZ_carb))
Gamma_dotdot_Z_carb_1000AA = np.concatenate(([Gamma_dotdot_Z_carb[0]], Gamma_dotdot_Z_carb))

# %%
print("Done")
# Out:
# Done

# %% [markdown]
# ---

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)

ax.plot(ZZ_sil_5AA+0.5, Gamma_dotdot_Z_sil_5AA*1.0e21, "-r", linewidth=2, linestyle="steps", label="silicate")
ax.plot(ZZ_carb_5AA+0.5, Gamma_dotdot_Z_carb_5AA*1.0e21, "-k", linewidth=2, linestyle="steps", label="carbonaceous")

#ax.plot([Zmin_sil, Zmin_sil], [2.0e-3, 400], "--r", linewidth=0.5)
#ax.plot([Zmax_sil, Zmax_sil], [2.0e-3, 400], "--r", linewidth=0.5)

#ax.plot([Zmin_carb, Zmin_carb], [2.0e-3, 400], "--k", linewidth=0.5)
#ax.plot([Zmax_carb, Zmax_carb], [2.0e-3, 400], "--k", linewidth=0.5)


ax.set_yscale("log")

ax.set_xlabel("Z", fontsize=20)
ax.set_ylabel("10$^{21} \\times$ $\Gamma^{''}_{pe}(a, Z, G)$ [ergs]", fontsize=18)

#ax.set_xlim(min(Zmin_sil, Zmin_carb)-1, max(Zmax_sil, Zmax_carb)+1)

ax.set_ylim(2.0e-3, 200)

#ax.text(3, 100, "100 $\\AA$", fontsize=18)

ax.legend(loc=1, fontsize=18)

ax.tick_params(axis='both', which='major', length=10, width=2,  labelsize=15, direction="in")
ax.tick_params(axis='both', which='minor', length=5, width=1.5, labelsize=15, direction="in")

ax.set_title("Heating Rate vs grain charge, a=%i $\AA$, G=1.7G$_{0}$"%asize, fontsize=18)

fig.show()

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)

ax.plot(ZZ_sil_100AA+0.5, Gamma_dotdot_Z_sil_100AA*1.0e21, "-k", linewidth=2, linestyle="steps", label="silicate")
ax.plot(ZZ_carb_100AA+0.5, Gamma_dotdot_Z_carb_100AA*1.0e21, "-r", linewidth=2, linestyle="steps", label="carbonaceous")

#ax.plot([Zmin_sil, Zmin_sil], [2.0e-3, 400], "--r", linewidth=0.5)
#ax.plot([Zmax_sil, Zmax_sil], [2.0e-3, 400], "--r", linewidth=0.5)

#ax.plot([Zmin_carb, Zmin_carb], [2.0e-3, 400], "--k", linewidth=0.5)
#ax.plot([Zmax_carb, Zmax_carb], [2.0e-3, 400], "--k", linewidth=0.5)


ax.set_yscale("log")

ax.set_xlabel("Z", fontsize=20)
ax.set_ylabel("10$^{21} \\times$ $\Gamma^{''}_{pe}(a, Z, G)$ [erg s$^{-1}$]", fontsize=18)

ax.set_xlim(-50, 60)

#ax.set_ylim(1.0e0, 5.0e5)

#ax.text(3, 100, "100 $\\AA$", fontsize=18)

ax.legend(loc=1, fontsize=18)

ax.tick_params(axis='both', which='major', length=10, width=2,  labelsize=15, direction="in")
ax.tick_params(axis='both', which='minor', length=5, width=1.5, labelsize=15, direction="in")

ax.set_title("Heating Rate vs grain charge, a=%i $\AA$, G=1.7G$_{0}$"%asize, fontsize=18)

fig.show()

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)

ax.plot(ZZ_sil_100AA+0.5, Gamma_dotdot_Z_sil_100AA*1.0e21, "-k", linewidth=2, linestyle="steps", label="silicate")
ax.plot(ZZ_carb_100AA+0.5, Gamma_dotdot_Z_carb_100AA*1.0e21, "-r", linewidth=2, linestyle="steps", label="carbonaceous")

#ax.plot([Zmin_sil, Zmin_sil], [2.0e-3, 400], "--r", linewidth=0.5)
#ax.plot([Zmax_sil, Zmax_sil], [2.0e-3, 400], "--r", linewidth=0.5)

#ax.plot([Zmin_carb, Zmin_carb], [2.0e-3, 400], "--k", linewidth=0.5)
#ax.plot([Zmax_carb, Zmax_carb], [2.0e-3, 400], "--k", linewidth=0.5)


ax.set_yscale("log")

ax.set_xlabel("Z", fontsize=20)
ax.set_ylabel("10$^{21} \\times$ $\Gamma^{''}_{pe}(a, Z, G)$ [erg s$^{-1}$]", fontsize=18)

ax.set_xlim(-25, 60)

ax.set_ylim(1.0e0, 5.0e5)

#ax.text(3, 100, "100 $\\AA$", fontsize=18)

ax.legend(loc=1, fontsize=18)

ax.tick_params(axis='both', which='major', length=10, width=2,  labelsize=15, direction="in")
ax.tick_params(axis='both', which='minor', length=5, width=1.5, labelsize=15, direction="in")

ax.set_title("Heating Rate vs grain charge, a=%i $\AA$, G=1.7G$_{0}$"%asize, fontsize=18)

fig.show()

# %% [markdown]
# ##### Make the panels

# %%
xsize = 14
ysize = 4

nfigs_x = 3
nfigs_y = 1

fig = plt.figure(figsize=(xsize, ysize))

hpad = 0.14
wpad = 0.075

xs_panel = 0.75 / nfigs_x 
ys_panel = 0.78 / nfigs_y 

############################################################################################################
############################               5 Angstroms             #######################################
############################################################################################################

ax = fig.add_axes([0, 0, 1, 1])

#ax.plot([0,1], [0,1], visible=False)
ax.set_xlim(0,1)
ax.set_ylim(0,1)

ax.text(0.2, 0.93, "5 $\AA$", fontsize=20, horizontalalignment='center')
ax.text(0.53, 0.93, "100 $\AA$", fontsize=20, horizontalalignment='center')
ax.text(0.87, 0.93, "1000 $\AA$", fontsize=20, horizontalalignment='center')

plt.axis('off')

#------------------------------------------------------------------------------------------------
# From bottom left, to upper right.
ii = 0
jj = 0


ax = fig.add_axes([wpad + ii*xs_panel+ii*wpad, hpad + jj*ys_panel, xs_panel, ys_panel])

ax.plot(ZZ_sil_5AA+0.5, Gamma_dotdot_Z_sil_5AA*1.0e21, "-k", linewidth=2, linestyle="steps", label="silicate")
ax.plot(ZZ_carb_5AA+0.5, Gamma_dotdot_Z_carb_5AA*1.0e21, "-r", linewidth=2, linestyle="steps", label="carbonaceous")

#ax.plot([Zmin_sil, Zmin_sil], [2.0e-1, 400], "--r", linewidth=0.5)
#ax.plot([Zmax_sil, Zmax_sil], [2.0e-1, 400], "--r", linewidth=0.5)

#ax.plot([Zmin_carb, Zmin_carb], [2.0e-1, 400], "--k", linewidth=0.5)
#ax.plot([Zmax_carb, Zmax_carb], [2.0e-1, 400], "--k", linewidth=0.5)


ax.legend(loc=0, fontsize=12, frameon=False)

ax.set_yscale("log")

ax.set_xlabel("Z", fontsize=20)
ax.set_ylabel("10$^{21} \\times$ $\Gamma^{''}_{pe}(a, Z)$ [erg s$^{-1}$]", fontsize=18)

#ax.set_xlim(min(Zmin_sil, Zmin_carb)-1, max(Zmax_sil, Zmax_carb)+1)

ax.set_ylim(1.0e-3, 5.0e2)

#ax.text(3, 100, "100 $\\AA$", fontsize=18)

#ax.legend(loc=0, fontsize=18)

ax.tick_params(axis='both', which='major', length=10, width=2,  labelsize=15, direction="in")
ax.tick_params(axis='both', which='minor', length=5, width=1.5, labelsize=15, direction="in")


#------------------------------------------------------------------------------------------------
# From bottom left, to upper right.
ii = 1
jj = 0

ax = fig.add_axes([wpad + ii*xs_panel+ii*wpad+0.01, hpad + jj*ys_panel, xs_panel, ys_panel])


ax.plot(ZZ_sil_100AA+0.5, Gamma_dotdot_Z_sil_100AA*1.0e21, "-k", linewidth=2, linestyle="steps", label="silicate")
ax.plot(ZZ_carb_100AA+0.5, Gamma_dotdot_Z_carb_100AA*1.0e21, "-r", linewidth=2, linestyle="steps", label="carbonaceous")

#ax.plot([Zmin_sil, Zmin_sil], [2.0e-1, 400], "--r", linewidth=0.5)
#ax.plot([Zmax_sil, Zmax_sil], [2.0e-1, 400], "--r", linewidth=0.5)

#ax.plot([Zmin_carb, Zmin_carb], [2.0e-1, 400], "--k", linewidth=0.5)
#ax.plot([Zmax_carb, Zmax_carb], [2.0e-1, 400], "--k", linewidth=0.5)

ax.set_yscale("log")

ax.set_xlabel("Z", fontsize=20)
ax.set_ylabel("10$^{21} \\times$ $\Gamma^{''}_{pe}(a, Z)$ [erg s$^{-1}$]", fontsize=18)

#ax.set_xlim(min(Zmin_sil, Zmin_carb)-1, max(Zmax_sil, Zmax_carb)+1)

ax.set_xlim(-22, 70)

ax.set_ylim(1.0e-2, 1.0e6)

#ax.text(3, 100, "100 $\\AA$", fontsize=18)

#ax.legend(loc=0, fontsize=18)

ax.tick_params(axis='both', which='major', length=10, width=2,  labelsize=15, direction="in")
ax.tick_params(axis='both', which='minor', length=5, width=1.5, labelsize=15, direction="in")

#------------------------------------------------------------------------------------------------
# From bottom left, to upper right.
ii = 2
jj = 0

ax = fig.add_axes([wpad + ii*xs_panel+ii*wpad+0.02, hpad + jj*ys_panel, xs_panel, ys_panel])


ax.plot(ZZ_sil_1000AA+0.5, Gamma_dotdot_Z_sil_1000AA*1.0e21, "-k", linewidth=2, linestyle="steps", label="silicate")
ax.plot(ZZ_carb_1000AA+0.5, Gamma_dotdot_Z_carb_1000AA*1.0e21, "-r", linewidth=2, linestyle="steps", label="carbonaceous")

#ax.plot([Zmin_sil, Zmin_sil], [2.0e-1, 400], "--r", linewidth=0.5)
#ax.plot([Zmax_sil, Zmax_sil], [2.0e-1, 400], "--r", linewidth=0.5)

#ax.plot([Zmin_carb, Zmin_carb], [2.0e-1, 400], "--k", linewidth=0.5)
#ax.plot([Zmax_carb, Zmax_carb], [2.0e-1, 400], "--k", linewidth=0.5)

ax.set_yscale("log")

ax.set_xlabel("Z", fontsize=20)
ax.set_ylabel("10$^{21} \\times$ $\Gamma^{''}_{pe}(a, Z)$ [erg s$^{-1}$]", fontsize=18)

ax.set_xlim(-220, 750)
#ax.set_xlim(min(Zmin_sil, Zmin_carb)-1, max(Zmax_sil, Zmax_carb)+1)

ax.set_ylim(1.0e-2, 1.0e10)

#ax.text(3, 100, "100 $\\AA$", fontsize=18)

#ax.legend(loc=0, fontsize=18)

ax.tick_params(axis='both', which='major', length=10, width=2,  labelsize=15, direction="in")
ax.tick_params(axis='both', which='minor', length=5, width=1.5, labelsize=15, direction="in")

fig.show()

fig.savefig("/home/jcibanezm/Dropbox/Projects/Papers/In_Progress/PeHeat_dust/Figures/Figure_2_Gamma_dotdot.pdf", format="pdf")

# %%
ilow = np.where(ZZ_sil_5AA == -1)[0][0]
iup  = np.where(ZZ_sil_5AA == 1)[0][0]

mZ_5AA    = np.log(Gamma_dotdot_Z_sil_5AA[iup]/Gamma_dotdot_Z_sil_5AA[ilow])/(ZZ_sil_5AA[iup]-ZZ_sil_5AA[ilow])

# %%
ilow = np.where(ZZ_sil_100AA == 0)[0][0]
iup  = np.where(ZZ_sil_100AA == 20)[0][0]

mZ_100AA  = np.log(Gamma_dotdot_Z_sil_100AA[iup]/Gamma_dotdot_Z_sil_100AA[ilow])/(ZZ_sil_100AA[iup]-ZZ_sil_100AA[ilow])

# %%
ilow = np.where(ZZ_sil_1000AA == 0)[0][0]
iup  = np.where(ZZ_sil_1000AA == 200)[0][0]

mZ_1000AA  = np.log(Gamma_dotdot_Z_sil_1000AA[iup]/Gamma_dotdot_Z_sil_1000AA[ilow])/(ZZ_sil_1000AA[iup]-ZZ_sil_1000AA[ilow])

# %%
print(mZ_5AA, mZ_100AA, mZ_1000AA)
# Out:
# (-3.620692757058897, -0.1134023238424188, -0.01351293075203859)

# %%
print(Gamma_dotdot_Z_sil_5AA)
# Out:
# [1.05072311e-19 1.05072311e-19 1.11937265e-20 7.52652513e-23
#  0.00000000e+00]

# %%
print(ZZpar_5)
# Out:
# [-2. -1.  0.  1.]

# %%
Gdd_par_5
# Out:
# array([2.93367535e-18, 7.85172656e-20, 2.10144623e-21, 5.62433780e-23])

# %%
ilow5 = np.where(ZZ_sil_5AA == -1)[0][0]
iup5  = np.where(ZZ_sil_5AA == 1)[0][0]

ZZpar_5 = np.arange(ZZ_sil_5AA[ilow5]-1, ZZ_sil_5AA[iup5]+1, 1)
Gdd_par_5 = Gamma_dotdot_Z_sil_5AA[ilow5] * np.exp(mZ_5AA*ZZpar_5) / 50.


ilow100 = np.where(ZZ_sil_100AA == 0)[0][0]
iup100  = np.where(ZZ_sil_100AA == 20)[0][0]

ZZpar_100   = np.arange(ZZ_sil_100AA[ilow100]-1, ZZ_sil_100AA[iup100]+1, 1)
Gdd_par_100 = Gamma_dotdot_Z_sil_100AA[ilow100] * np.exp(mZ_100AA*ZZpar_100)

ilow1000 = np.where(ZZ_sil_1000AA == 0)[0][0]
iup1000  = np.where(ZZ_sil_1000AA == 200)[0][0]

ZZpar_1000   = np.arange(ZZ_sil_1000AA[ilow1000]-1, ZZ_sil_1000AA[iup1000]+1, 1)
Gdd_par_1000 = Gamma_dotdot_Z_sil_1000AA[ilow1000] * np.exp(mZ_1000AA*ZZpar_1000)

# %%
xsize = 14
ysize = 4

nfigs_x = 3
nfigs_y = 1

fig = plt.figure(figsize=(xsize, ysize))

hpad = 0.14
wpad = 0.075

xs_panel = 0.75 / nfigs_x 
ys_panel = 0.78 / nfigs_y 

############################################################################################################
############################               5 Angstroms             #######################################
############################################################################################################

ax = fig.add_axes([0, 0, 1, 1])
ax.set_xlim(0,1)
ax.set_ylim(0,1)

ax.text(0.2, 0.93, "5 $\AA$", fontsize=20, horizontalalignment='center')
ax.text(0.53, 0.93, "100 $\AA$", fontsize=20, horizontalalignment='center')
ax.text(0.87, 0.93, "1000 $\AA$", fontsize=20, horizontalalignment='center')

plt.axis('off')

#------------------------------------------------------------------------------------------------
# From bottom left, to upper right.
ii = 0
jj = 0

ax = fig.add_axes([wpad + ii*xs_panel+ii*wpad, hpad + jj*ys_panel, xs_panel, ys_panel])

ax.plot(ZZ_sil_5AA+0.5, Gamma_dotdot_Z_sil_5AA*1.0e21, "-k", linewidth=2, linestyle="steps", label="silicate")
#ax.plot(ZZ_carb_5AA+0.5, Gamma_dotdot_Z_carb_5AA*1.0e21, "-r", linewidth=2, linestyle="steps", label="carbonaceous")

ax.plot(ZZpar_5+0.5, Gdd_par_5*1.0e21, "-b", linewidth=2, linestyle="steps")

ax.legend(loc=0, fontsize=12, frameon=False)

ax.set_yscale("log")

ax.set_xlabel("Z", fontsize=20)
ax.set_ylabel("10$^{21} \\times$ $\Gamma^{''}_{pe}(a, Z)$ [erg s$^{-1}$]", fontsize=18)

ax.set_xlim()
ax.set_ylim(1.0e-3, 5.0e2)

ax.tick_params(axis='both', which='major', length=10, width=2,  labelsize=15, direction="in")
ax.tick_params(axis='both', which='minor', length=5, width=1.5, labelsize=15, direction="in")

#------------------------------------------------------------------------------------------------
# From bottom left, to upper right.
ii = 1
jj = 0

ax = fig.add_axes([wpad + ii*xs_panel+ii*wpad+0.01, hpad + jj*ys_panel, xs_panel, ys_panel])

ax.plot(ZZ_sil_100AA+0.5, Gamma_dotdot_Z_sil_100AA*1.0e21, "-k", linewidth=2, linestyle="steps", label="silicate")
#ax.plot(ZZ_carb_100AA+0.5, Gamma_dotdot_Z_carb_100AA*1.0e21, "-r", linewidth=2, linestyle="steps", label="carbonaceous")

ax.plot(ZZpar_100+0.5, Gdd_par_100*1.0e21, "-b", linewidth=2, linestyle="steps")

ax.set_yscale("log")

ax.set_xlabel("Z", fontsize=20)
ax.set_ylabel("10$^{21} \\times$ $\Gamma^{''}_{pe}(a, Z)$ [erg s$^{-1}$]", fontsize=18)

ax.set_xlim(ZZ_sil_100AA[ilow100]-10, ZZ_sil_100AA[iup100]+10)
ax.set_ylim(1.0e3, 5.0e5)

ax.tick_params(axis='both', which='major', length=10, width=2,  labelsize=15, direction="in")
ax.tick_params(axis='both', which='minor', length=5, width=1.5, labelsize=15, direction="in")

#------------------------------------------------------------------------------------------------
# From bottom left, to upper right.
ii = 2
jj = 0

ax = fig.add_axes([wpad + ii*xs_panel+ii*wpad+0.02, hpad + jj*ys_panel, xs_panel, ys_panel])

ax.plot(ZZ_sil_1000AA+0.5, Gamma_dotdot_Z_sil_1000AA*1.0e21, "-k", linewidth=2, linestyle="steps", label="silicate")
#ax.plot(ZZ_carb_1000AA+0.5, Gamma_dotdot_Z_carb_1000AA*1.0e21, "-r", linewidth=2, linestyle="steps", label="carbonaceous")

ax.plot(ZZpar_1000+0.5, Gdd_par_1000*1.0e21, "-b", linewidth=2, linestyle="steps")

#ax.plot(ZZpar_1000+0.5, Gamma_dotdot_Z_sil_1000AA[ilow1000-1:iup1000+1]/Gdd_par_1000, "-b", linewidth=2, linestyle="steps")

ax.set_yscale("log")

ax.set_xlabel("Z", fontsize=20)
#ax.set_ylabel("10$^{21} \\times$ $\Gamma^{''}_{pe}(a, Z)$ [erg s$^{-1}$]", fontsize=18)

ax.set_xlim(ZZ_sil_1000AA[ilow1000]-50, ZZ_sil_1000AA[iup1000]+50)

ax.set_ylim(5.0e4, 5.0e7)
#ax.set_ylim(1, 1.5)

ax.tick_params(axis='both', which='major', length=10, width=2,  labelsize=15, direction="in")
ax.tick_params(axis='both', which='minor', length=5, width=1.5, labelsize=15, direction="in")

fig.show()

# %%
fig = plt.figure()

ax = fig.add_subplot(111)

ax.plot([5, 100, 1000], np.abs([mZ_5AA, mZ_100AA, mZ_1000AA]))

ax.set_xscale("log")
ax.set_yscale("log")

fig.show()

# %% [markdown]
# ---
# ## Now do a Bayesian Fit to the heating as a function of charge

# %% [markdown]
# # Silicates, 5 Angstroms

# %%
import emcee

# %%
def plot_data():
    plt.plot(x, y, "-k", linewidth=2, linestyle="steps", )
    #plt.xlim(-2.2,1.2)
    #plt.ylim(-52,-41)
    
    plt.xlabel("Z", fontsize=15)
    plt.ylabel("$\Gamma^{''}_{pe}(a, Z)$ [erg s$^{-1}$]", fontsize=13)

    plt.tick_params(axis='both', which='major', length=10, width=2,  labelsize=10, direction="in")
    plt.tick_params(axis='both', which='minor', length=5, width=1.5, labelsize=10, direction="in")

    return

plot_data()

# %%
x = ZZ_sil_5AA[0:len(ZZ_sil_5AA)-1]
y = np.log(Gamma_dotdot_Z_sil_5AA[0:len(x)])

# %%
def ln_likelihood(x, y, modelfunc, params):
    model_y = modelfunc(params, x)
    chi = (y - model_y)
    return -0.5*np.sum(chi**2)

# %%
## Prior: all parameter values must be within boundaries set here
BOUNDARIES = [(-100,100),(-100,100),(-100,100),(-100,100)]

def ln_prior(params, bound=BOUNDARIES):
    result = 0.0
    for i in range(len(params)):
        if params[i]<bound[i][0] or params[i]>bound[i][1] : result = -np.inf 
    return result

# %%
## Here's a linear model with parameters m and b
def lin_model(params, x):
    m, b = params
    return m*x + b

# %%
def lnprob(params, x, y):
    return ln_likelihood(x, y, lin_model, params) + ln_prior(params)

# %%
NWALKERS = 100
NDIMS    = 2
theta0   = np.zeros(shape=(NWALKERS,NDIMS))

# %%
## By eye fit: slope = 3/5 = 0.6, b = 6
## Initialize around those values
theta0[:,0] = np.random.uniform(-100.0,100.0,NWALKERS)
theta0[:,1] = np.random.uniform(-100.0,100.0,NWALKERS)

# %%
sampler = emcee.EnsembleSampler(NWALKERS, NDIMS, lnprob, args=[x,y])

# %%
NBURN = 100
theta, prob, state = sampler.run_mcmc(theta0, NBURN)

# %%
sampler.reset()

# %%
NSTEPS = 1000
theta2, prob2, state2 = sampler.run_mcmc(theta, NSTEPS)

# %%
median5 = np.quantile(sampler.flatchain, 0.5, axis=0)

# %%
## Plot final state
plot_data()

for th in theta2:
    plt.plot(x, lin_model(th,x), 'r-', lw=1, alpha=0.3)

plt.plot(x, lin_model(median,x), 'r-', lw=2, alpha=1, linestyle="steps")
    
plt.title('After 1000 steps')

# %% [markdown]
# ---

# %%
def quad_model(params, x):
    m, b, a = params
    return a*x**2 + m*x + b

# %%
def lnprob_quad(params, x, y):
    return ln_likelihood(x, y, quad_model, params) + ln_prior(params)

# %%
NWALKERS = 100
NDIMS    = 3

quadsampler = emcee.EnsembleSampler(NWALKERS, NDIMS, lnprob_quad, args=(x,y))

# %%
## Initialize new walkers
theta0 = np.zeros(shape=(NWALKERS,NDIMS))
theta0[:,0] = np.random.uniform(-100,100,NWALKERS)
theta0[:,1] = np.random.uniform(-100,100,NWALKERS)
theta0[:,2] = np.random.uniform(-100,100,NWALKERS)

# %%
NBURN = 1000
theta, prob, state = quadsampler.run_mcmc(theta0, NBURN)

# %%
medianquad = np.quantile(quadsampler.flatchain, 0.5, axis=0)

# %%
print(medianquad)
# Out:
# [ -3.65665771 -45.95367139  -1.28402997]

# %%
plot_data()

#for th in theta:
#    plt.plot(x, quad_model(th,x), 'b-', alpha=0.3)
    
plt.plot(x, quad_model(medianquad,x), 'b-', lw=2, alpha=1, linestyle="steps")

# %% [markdown]
# # Silicates, 100 Angstroms

# %%
ilow = np.where(ZZ_sil_100AA == 0)[0][0]
iup  = np.where(ZZ_sil_100AA == 20)[0][0]

x = ZZ_sil_100AA[ilow:iup]
y = np.log(Gamma_dotdot_Z_sil_100AA[ilow:iup])

# %% [markdown]
# I should make a function that goes over the different sizes, does an MCMC first order or second order run, and gets the medianvalues.|

# %%
# Linear regression to the 100 Angstroms silicate grains.

NWALKERS = 100
NDIMS    = 2
theta0   = np.zeros(shape=(NWALKERS,NDIMS))

## By eye fit: slope = 3/5 = 0.6, b = 6
## Initialize around those values
theta0[:,0] = np.random.uniform(-100.0,100.0,NWALKERS)
theta0[:,1] = np.random.uniform(-100.0,100.0,NWALKERS)

sampler100 = emcee.EnsembleSampler(NWALKERS, NDIMS, lnprob, args=[x,y])

NBURN = 100
theta, prob, state = sampler100.run_mcmc(theta0, NBURN)

sampler100.reset()

NSTEPS = 1000
theta2, prob2, state2 = sampler100.run_mcmc(theta, NSTEPS)

median100 = np.quantile(sampler100.flatchain, 0.5, axis=0)

print(median100)
# Out:
# [ -0.11124553 -37.11442987]

# %%
## Plot final state
plot_data()

#for th in theta2:
#    plt.plot(x, lin_model(th,x), 'r-', lw=1, alpha=0.3)

plt.plot(x, lin_model(median100,x), 'r-', lw=2, alpha=1, linestyle="steps")

plt.title("Linear fit", fontsize=20)

# %%
NWALKERS = 100
NDIMS    = 3

quadsampler100 = emcee.EnsembleSampler(NWALKERS, NDIMS, lnprob_quad, args=(x,y))

## Initialize new walkers
theta0 = np.zeros(shape=(NWALKERS,NDIMS))
theta0[:,0] = np.random.uniform(-100,100,NWALKERS)
theta0[:,1] = np.random.uniform(-100,100,NWALKERS)
theta0[:,2] = np.random.uniform(-100,100,NWALKERS)

NBURN = 1000
theta, prob, state = quadsampler100.run_mcmc(theta0, NBURN)

medianquad100 = np.quantile(quadsampler100.flatchain, 0.5, axis=0)

print(medianquad)
# Out:
# [ -3.65665771 -45.95367139  -1.28402997]

# %%
plot_data()

#for th in theta:
#    plt.plot(x, quad_model(th,x), 'b-', alpha=0.3)
    
plt.plot(x, quad_model(medianquad100,x), 'b-', lw=2, alpha=1, linestyle="steps")

plt.title("Quadratic fit", fontsize=20)

# %% [markdown]
# ---

# %%
def LinearMCMC(x, y):
    """
    Use emcee to do a MCMC Bayesian parameter estimation of the heating as a function of charge.
    Linear fit to the 
    """
    # Linear regression
    NWALKERS = 100
    NDIMS    = 2
    theta0   = np.zeros(shape=(NWALKERS,NDIMS))

    ## Initialize around those values
    theta0[:,0] = np.random.uniform(-100.0,100.0,NWALKERS)
    theta0[:,1] = np.random.uniform(-100.0,100.0,NWALKERS)

    sampler = emcee.EnsembleSampler(NWALKERS, NDIMS, lnprob, args=[x,y])

    NBURN = 100
    theta, prob, state = sampler.run_mcmc(theta0, NBURN)

    sampler.reset()

    NSTEPS = 1000
    theta2, prob2, state2 = sampler.run_mcmc(theta, NSTEPS)

    median = np.quantile(sampler.flatchain, 0.5, axis=0)
    
    return median, sampler, theta

# %%
def QuadMCMC(x, y):
    
    NWALKERS = 100
    NDIMS    = 3

    quadsampler = emcee.EnsembleSampler(NWALKERS, NDIMS, lnprob_quad, args=(x,y))

    ## Initialize new walkers
    theta0 = np.zeros(shape=(NWALKERS,NDIMS))
    theta0[:,0] = np.random.uniform(-100,100,NWALKERS)
    theta0[:,1] = np.random.uniform(-100,100,NWALKERS)
    theta0[:,2] = np.random.uniform(-100,100,NWALKERS)

    NBURN = 1000
    theta, prob, state = quadsampler.run_mcmc(theta0, NBURN)
    
    quadsampler.reset()

    NSTEPS = 1000
    theta2, prob2, state2 = quadsampler.run_mcmc(theta, NSTEPS)

    median = np.quantile(quadsampler.flatchain, 0.5, axis=0)
    
    return median, sampler, theta2

# %% [markdown]
# ---

# %% [markdown]
# # 1000 Angstroms

# %%
ilow1000 = np.where(ZZ_sil_1000AA == 0)[0][0]
iup1000  = np.where(ZZ_sil_1000AA == 200)[0][0]

x = ZZ_sil_1000AA[ilow1000:iup1000]
y = np.log(Gamma_dotdot_Z_sil_1000AA[ilow1000:iup1000])

# %%
medianlin1000, samplerlin1000, thetalin1000 = LinearMCMC(x, y)

# %%
medianquad1000, samplerquad1000, thetaquad1000 = QuadMCMC(x, y)

# %%
plot_data()

plt.plot(x, lin_model(medianlin1000,x), 'r-', lw=2, alpha=1, linestyle="steps")

plt.title("Linear fit, 1000 A", fontsize=20)

# %%
plot_data()

plt.plot(x, quad_model(medianquad1000,x), 'b-', lw=2, alpha=1, linestyle="steps")

plt.title("Quadratic fit, 1000 A", fontsize=20)

# %%
print(median)
print(median100)
print(medianlin1000)

medianlin = np.array([median, median100, medianlin1000])
# Out:
# [ -2.38821073 -47.25954921]
# [ -0.11124553 -37.11442987]
# [-1.36423070e-02 -3.29414357e+01]

# %%
print(medianquad)
print(medianquad100)
print(medianquad1000)

medianquad =  np.array([medianquad, medianquad100, medianquad1000])
# Out:
# [ -3.65665771 -45.95367139  -1.28402997]
# [-6.69199875e-02 -3.72248936e+01 -2.40891885e-03]
# [-8.58424234e-03 -3.31082307e+01 -2.55153256e-05]

# %%
asize = [5., 100., 1000.]

# %%
figure = plt.figure(figsize=(10,4))
ax = figure.add_subplot(121)
ax.plot(asize, np.abs(medianlin[:,0]), "-k", linewidth=2)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_title("Slope")

ax = figure.add_subplot(122)
ax.plot(asize, np.abs(medianlin[:,1]), "-k", linewidth=2)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_title("intercept")

#fig.suptitle("Parameters for the linear fit", fontsize=18)

fig.show()

# %%
figure = plt.figure(figsize=(16,4))
ax = figure.add_subplot(131)
ax.plot(asize, np.abs(medianquad[:,2]), "-k", linewidth=2)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_title("quad term")

ax = figure.add_subplot(132)
ax.plot(asize, np.abs(medianquad[:,0]), "-k", linewidth=2)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_title("slope")

ax = figure.add_subplot(133)
ax.plot(asize, np.abs(medianquad[:,1]), "-k", linewidth=2)

ax.set_xscale("log")
ax.set_yscale("log")

ax.set_title("intercept")

fig.show()
